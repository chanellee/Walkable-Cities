# %%
import pandas as pd

city_pop = pd.read_csv("sub-est2021_all.csv",encoding='latin-1')
# Out:
#        SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0          40      1       0      0       0       0             0        A
# 1         162      1       0    124       0       0             0        A
# 2         162      1       0    460       0       0             0        A
# 3         162      1       0    484       0       0             0        A
# 4         162      1       0    676       0       0             0        A
# ...       ...    ...     ...    ...     ...     ...           ...      ...
# 81411     157     56      43  99990       0       0             1        F
# 81412      50     56      45      0       0       0             0        A
# 81413     157     56      45  56215       0       0             1        A
# 81414     157     56      45  79125       0       0             1        A
# 81415     157     56      45  99990       0       0             1        F
#
#                              NAME   STNAME  ESTIMATESBASE2020  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 import cenpy
#       2 acs = cenpy.products.ACS()
# ----> 3 acs.from_place(place_type="City")
#
# TypeError: from_place() missing 1 required positional argument: 'place'
