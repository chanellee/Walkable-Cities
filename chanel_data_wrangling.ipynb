# %%
import pandas as pd
#city_pop = pd.read_csv("sub-est2021_all.csv",encoding='latin-1')
#city_land = pd.read_csv("2020_Gaz_place_national.txt",sep = "\t",encoding='latin-1')
#age_sex = pd.read_csv("Age_and_Sex_2021-Data.csv",encoding='latin-1')
#education = pd.read_csv("Education_2021-Data.csv",encoding='latin-1')
#housing = pd.read_csv("Housing_2021-Data.csv",encoding='latin-1')
#race = pd.read_csv("Race_2020.p1-Data.csv",encoding='latin-1')

#state_codes = pd.read_csv("state_codes.csv")

# %%
city_pop = pd.read_csv("sub-est2021_all.csv",encoding='latin-1')
state_codes = pd.read_csv("state_codes.csv")

city_pop = city_pop[["NAME", "STNAME","POPESTIMATE2021"]]
city_only = [i.lower().__contains__("city") for i in city_pop["NAME"]] 
city_pop = city_pop[city_only]
city_pop = city_pop[city_pop["POPESTIMATE2021"]>=50000]
city_pop = city_pop.set_axis(['city', 'state', 'pop_estimate_2021'], axis='columns', copy = False)
city_pop["city"] = [i.replace(" city","") for i in city_pop["city"]]
city_pop["city"] = [i.replace(" City","") for i in city_pop["city"]]
city_pop["city"] = [i.replace(" (pt.)","") for i in city_pop["city"]]
state_codes = state_codes[["state","code"]].set_axis(['state', 'state_code'], axis='columns', copy = False)
city_pop = pd.merge(city_pop,state_codes, on = "state", how = "left")
city_pop["city_state"] = city_pop["city"] + ", " + city_pop["state"]
city_pop["city_state_code"] = city_pop["city"] + ", " + city_pop["state_code"]
city_pop
# Out:
#             city      state  pop_estimate_2021 state_code  \
# 0         Auburn    Alabama              78564         AL
# 1     Birmingham    Alabama             197575         AL
# 2        Decatur    Alabama              57804         AL
# 3         Dothan    Alabama              71175         AL
# 4         Hoover    Alabama              92589         AL
# ...          ...        ...                ...        ...
# 1871     Oshkosh  Wisconsin              66607         WI
# 1872      Casper    Wyoming              58656         WY
# 1873    Cheyenne    Wyoming              65051         WY
# 1874    Cheyenne    Wyoming              65051         WY
# 1875      Casper    Wyoming              58656         WY
#
#                city_state city_state_code
# 0         Auburn, Alabama      Auburn, AL
# 1     Birmingham, Alabama  Birmingham, AL
# 2        Decatur, Alabama     Decatur, AL
# 3         Dothan, Alabama      Dothan, AL
# 4         Hoover, Alabama      Hoover, AL
# ...                   ...             ...
# 1871   Oshkosh, Wisconsin     Oshkosh, WI
# 1872      Casper, Wyoming      Casper, WY
# 1873    Cheyenne, Wyoming    Cheyenne, WY
# 1874    Cheyenne, Wyoming    Cheyenne, WY
# 1875      Casper, Wyoming      Casper, WY
#
# [1876 rows x 6 columns]

# %%
city_land = pd.read_csv("2020_Gaz_place_national.txt",sep = "\t",encoding='latin-1')
state_codes = pd.read_csv("state_codes.csv")

city_only = [i.lower().__contains__("city") for i in city_land["NAME"]]
city_land= city_land[city_only]
test = city_land[["USPS","NAME","ALAND"]].set_axis(['state_code', 'city', 'land_area_sqm'], axis='columns', copy = False)

city_land = pd.merge(test,state_codes[["state","code"]], left_on = "state_code", right_on = "code", how = "left")
city_land["city"] = [i.replace(" city","") for i in city_land["city"]]
city_land["city"] = [i.replace(" City","") for i in city_land["city"]]

del city_land["code"]
city_land["city_state"] = city_land["city"] + ", " + city_land["state"]
city_land["city_state_code"] = city_land["city"] + ", " + city_land["state_code"]
city_land["land_area_sqkm"] = city_land["land_area_sqm"]*0.000001
city_land
# Out:
#       state_code          city  land_area_sqm    state             city_state  \
# 0             AL     Abbeville       40255362  Alabama     Abbeville, Alabama
# 1             AL    Adamsville       67895675  Alabama    Adamsville, Alabama
# 2             AL     Alabaster       65472841  Alabama     Alabaster, Alabama
# 3             AL   Albertville       69770754  Alabama   Albertville, Alabama
# 4             AL     Alexander      113186307  Alabama     Alexander, Alabama
# ...          ...           ...            ...      ...                    ...
# 10507         WY      Riverton       26780417  Wyoming      Riverton, Wyoming
# 10508         WY  Rock Springs       51160520  Wyoming  Rock Springs, Wyoming
# 10509         WY      Sheridan       32850653  Wyoming      Sheridan, Wyoming
# 10510         WY    Torrington        9644842  Wyoming    Torrington, Wyoming
# 10511         WY       Worland       11882743  Wyoming       Worland, Wyoming
#
#         city_state_code  land_area_sqkm
# 0         Abbeville, AL       40.255362
# 1        Adamsville, AL       67.895675
# 2         Alabaster, AL       65.472841
# 3       Albertville, AL       69.770754
# 4         Alexander, AL      113.186307
# ...                 ...             ...
# 10507      Riverton, WY       26.780417
# 10508  Rock Springs, WY       51.160520
# 10509      Sheridan, WY       32.850653
# 10510    Torrington, WY        9.644842
# 10511       Worland, WY       11.882743
#
# [10512 rows x 7 columns]

# %%
walking_data = pd.merge(city_pop,city_land[["city_state","land_area_sqkm"]], on = "city_state", how = "left")
walking_data["pop_estimate_2021"]
walking_data["pop_per_km2"] = walking_data["pop_estimate_2021"]/walking_data["land_area_sqkm"]
walking_data = walking_data.drop_duplicates()
walking_data
#walking_data.to_csv("walkable-cities.csv", index = False)
# Out:
#             city      state  pop_estimate_2021 state_code  \
# 0         Auburn    Alabama              78564         AL
# 1     Birmingham    Alabama             197575         AL
# 2        Decatur    Alabama              57804         AL
# 3         Dothan    Alabama              71175         AL
# 4         Hoover    Alabama              92589         AL
# ...          ...        ...                ...        ...
# 1835  West Allis  Wisconsin              59484         WI
# 1842  Eau Claire  Wisconsin              67240         WI
# 1857    Appleton  Wisconsin              62343         WI
# 1872      Casper    Wyoming              58656         WY
# 1873    Cheyenne    Wyoming              65051         WY
#
#                  city_state city_state_code  land_area_sqkm  pop_per_km2
# 0           Auburn, Alabama      Auburn, AL      157.084761   500.137630
# 1       Birmingham, Alabama  Birmingham, AL      380.801025   518.840515
# 2          Decatur, Alabama     Decatur, AL      140.785624   410.581694
# 3           Dothan, Alabama      Dothan, AL      232.650562   305.930918
# 4           Hoover, Alabama      Hoover, AL      124.490626   743.742746
# ...                     ...             ...             ...          ...
# 1835  West Allis, Wisconsin  West Allis, WI       29.477371  2017.954722
# 1842  Eau Claire, Wisconsin  Eau Claire, WI       85.102803   790.103235
# 1857    Appleton, Wisconsin    Appleton, WI       64.203007   971.029285
# 1872        Casper, Wyoming      Casper, WY       68.757037   853.090863
# 1873      Cheyenne, Wyoming    Cheyenne, WY       83.549538   778.591977
#
# [888 rows x 8 columns]

# %%
walkable_cities = pd.read_csv("walkable-cities.csv")
walkable_cities
# Out:
#             city      state  pop_estimate_2021 state_code  \
# 0         Auburn    Alabama              78564         AL
# 1         Auburn    Alabama              78564         AL
# 2     Birmingham    Alabama             197575         AL
# 3     Birmingham    Alabama             195669         AL
# 4        Decatur    Alabama              57804         AL
# ...          ...        ...                ...        ...
# 1865  West Allis  Wisconsin              59484         WI
# 1866      Casper    Wyoming              58656         WY
# 1867      Casper    Wyoming              58656         WY
# 1868    Cheyenne    Wyoming              65051         WY
# 1869    Cheyenne    Wyoming              65051         WY
#
#                  city_state city_state_code  land_area_sqkm
# 0           Auburn, Alabama      Auburn, AL      157.084761
# 1           Auburn, Alabama      Auburn, AL      157.084761
# 2       Birmingham, Alabama  Birmingham, AL      380.801025
# 3       Birmingham, Alabama  Birmingham, AL      380.801025
# 4          Decatur, Alabama     Decatur, AL      140.785624
# ...                     ...             ...             ...
# 1865  West Allis, Wisconsin  West Allis, WI       29.477371
# 1866        Casper, Wyoming      Casper, WY       68.757037
# 1867        Casper, Wyoming      Casper, WY       68.757037
# 1868      Cheyenne, Wyoming    Cheyenne, WY       83.549538
# 1869      Cheyenne, Wyoming    Cheyenne, WY       83.549538
#
# [1870 rows x 7 columns]
